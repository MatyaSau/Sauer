# %% [markdown]
# <a href="https://colab.research.google.com/github/MatyaSau/Sauer/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vojenske_letouny_list = [
    ("F-22 Raptor", "1997", 2410),
    ("F-35A Lightning II", "2006", 1930),
    ("F-16 Fighting Falcon", "1974", 2414),
    ("F/A-18E Super Hornet", "1995", 1915),
    ("F-15E Strike Eagle", "1986", 2655),

    ("Eurofighter Typhoon", "1994", 2495),
    ("Dassault Rafale", "1986", 1912),
    ("Saab JAS 39 Gripen", "1988", 2470),
    ("Panavia Tornado IDS", "1974", 2400),

    ("Sukhoi Su-35", "2008", 2400),
    ("Sukhoi Su-57", "2010", 2600),
    ("Sukhoi Su-27", "1982", 2500),
    ("Mikoyan MiG-29", "1977", 2450),
    ("Mikoyan MiG-31", "1975", 3000),

    ("Chengdu J-10", "1998", 2350),
    ("Chengdu J-20", "2011", 2100),
    ("Shenyang J-11", "1998", 2500),

    ("HAL Tejas", "2001", 2205),
    ("KAI KF-21 Boramae", "2022", 1400),

    ("McDonnell Douglas F-4 Phantom II", "1958", 2370),
    ("Mikoyan MiG-21", "1955", 2230),
    ("Lockheed F-104 Starfighter", "1954", 2400),

    ("Northrop F-5E Tiger II", "1972", 1700),
    ("Sukhoi Su-24", "1970", 1700),
    ("Sukhoi Su-30SM", "2012", 2125),
    ("Sukhoi Su-34", "1990", 1900),
    ("Mikoyan MiG-23", "1967", 2500),

    ("McDonnell Douglas AV-8B Harrier II", "1981", 1085),
    ("Fairchild Republic A-10 Thunderbolt II", "1972", 706),
    ("Boeing F-15C", "1979", 2655),
    ("Boeing F/A-18C Hornet", "1978", 1915),
    ("Lockheed Martin F-117 Nighthawk", "1981", 1035),

    ("Grumman F-14 Tomcat", "1970", 2485),
    ("Dassault Mirage 2000", "1978", 2336),
    ("Dassault Mirage III", "1956", 2200),
    ("Saab 35 Draken", "1955", 2124),
    ("Saab 37 Viggen", "1967", 2230),

    ("Tupolev Tu-22M3 Backfire", "1977", 2300),
    ("Shenyang J-8", "1969", 2330),
    ("Northrop Grumman B-2 Spirit", "1989", 1010),
    ("Rockwell B-1B Lancer", "1984", 1334),
    ("Tupolev Tu-160 Blackjack", "1981", 2200)
]




vojenske_letouny_list.append(("Boeing F-15EX Eagle II", "2021", 2655))



for model, _, _ in vojenske_letouny_list:
    print(f"— {model} —\n")


print("Seřazeno podle rychlosti:")
sezareno_podle_rychlosti = sorted(vojenske_letouny_list, key=lambda x: x[2], reverse=True)
for model, year, speed in sezareno_podle_rychlosti:
    print(f"{model} – {speed} km/h")

print()

print("Letadla, rychlejší než 2200 km/h:")
rychle_a_zbesile = [i for i in vojenske_letouny_list if i[2] > 2200]
for model, year, speed in rychle_a_zbesile:
    print(f"{model} – {speed} km/h")

fastest = max(vojenske_letouny_list, key=lambda x: x[2])
print(f"Nejrychlejší je {fastest[0]} – {fastest[2]} km/h")
print()


prum_rychlost = sum([x[2] for x in vojenske_letouny_list]) / len(vojenske_letouny_list)
print("Průměrná rychlost z celého sezanmu je", prum_rychlost)
print()


#GRAF

import matplotlib.pyplot as plt

jmena = [x[0] for x in vojenske_letouny_list]
rychlosti = [x[2] for x in vojenske_letouny_list]

plt.figure(figsize=(12, 6))
plt.barh(jmena, rychlosti)
plt.title("Maximální rychlosti bojových letadel (km/h)")
plt.xlabel("Rychlost (km/h)")
plt.ylabel("Letadlo")
plt.tight_layout()
plt.show()





vojenske_letouny_list.append(("Boeing F-15EX Eagle II", "2021", 2655))



for model, _, _ in vojenske_letouny_list:
    print(f"— {model} —\n")


print("Seřazeno podle rychlosti:")
sezareno_podle_rychlosti = sorted(vojenske_letouny_list, key=lambda x: x[2], reverse=True)
for model, year, speed in sezareno_podle_rychlosti:
    print(f"{model} – {speed} km/h")

print()

print("Letadla, rychlejší než 2200 km/h:")
rychle_a_zbesile = [i for i in vojenske_letouny_list if i[2] > 2200]
for model, year, speed in rychle_a_zbesile:
    print(f"{model} – {speed} km/h")

fastest = max(vojenske_letouny_list, key=lambda x: x[2])
print(f"Nejrychlejší je {fastest[0]} – {fastest[2]} km/h")
print()


prum_rychlost = sum([x[2] for x in vojenske_letouny_list]) / len(vojenske_letouny_list)
print("Průměrná rychlost z celého sezanmu je", prum_rychlost)
print()


#GRAF

import matplotlib.pyplot as plt

jmena = [x[0] for x in vojenske_letouny_list]
rychlosti = [x[2] for x in vojenske_letouny_list]

plt.figure(figsize=(12, 6))
plt.barh(jmena, rychlosti)
plt.title("Maximální rychlosti bojových letadel (km/h)")
plt.xlabel("Rychlost (km/h)")
plt.ylabel("Letadlo")
plt.tight_layout()
plt.show()
# Out:
# — F-22 Raptor —
#
# — F-35A Lightning II —
#
# — F-16 Fighting Falcon —
#
# — F/A-18E Super Hornet —
#
# — F-15E Strike Eagle —
#
# — Eurofighter Typhoon —
#
# — Dassault Rafale —
#
# — Saab JAS 39 Gripen —
#
# — Panavia Tornado IDS —
#
# — Sukhoi Su-35 —
#
# — Sukhoi Su-57 —
#
# — Sukhoi Su-27 —
#
# — Mikoyan MiG-29 —
#
# — Mikoyan MiG-31 —
#
# — Chengdu J-10 —
#
# — Chengdu J-20 —
#
# — Shenyang J-11 —
#
# — HAL Tejas —
#
# — KAI KF-21 Boramae —
#
# — McDonnell Douglas F-4 Phantom II —
#
# — Mikoyan MiG-21 —
#
# — Lockheed F-104 Starfighter —
#
# — Northrop F-5E Tiger II —
#
# — Sukhoi Su-24 —
#
# — Sukhoi Su-30SM —
#
# — Sukhoi Su-34 —
#
# — Mikoyan MiG-23 —
#
# — McDonnell Douglas AV-8B Harrier II —
#
# — Fairchild Republic A-10 Thunderbolt II —
#
# — Boeing F-15C —
#
# — Boeing F/A-18C Hornet —
#
# — Lockheed Martin F-117 Nighthawk —
#
# — Grumman F-14 Tomcat —
#
# — Dassault Mirage 2000 —
#
# — Dassault Mirage III —
#
# Lockheed F-104 Starfighter – 2400 km/h
# Mikoyan MiG-23 – 2500 km/h
# Boeing F-15C – 2655 km/h
# Grumman F-14 Tomcat – 2485 km/h
# Dassault Mirage 2000 – 2336 km/h
# Saab 37 Viggen – 2230 km/h
# Tupolev Tu-22M3 Backfire – 2300 km/h
# Shenyang J-8 – 2330 km/h
# Boeing F-15EX Eagle II – 2655 km/h
# Nejrychlejší je Mikoyan MiG-31 – 3000 km/h
#
# Průměrná rychlost z celého sezanmu je 2130.953488372093

# %% [markdown]
# # Task
# The `ColabTurtle` library does not have a `fillcolor()` function. Instead, you should use the `color()` function with a single argument to set both the pen color and the fill color.
#
# Therefore, modify the `draw_sun`, `draw_sand`, and `draw_pyramid` functions to replace calls to `pencolor()` immediately followed by `fillcolor()` with a single `color()` call specifying the desired fill color. This will set both the pen and fill to that color during the drawing of the filled shape.

# %% [markdown]
# ## fix_colorturtle_fillcolor
#
# ### Subtask:
# Modify the `draw_sun`, `draw_sand`, and `draw_pyramid` functions to use the `color()` function with a single argument, as `fillcolor()` is not defined and `color(pencolor, fillcolor)` is not supported in ColabTurtle.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `draw_sun`, `draw_sand`, and `draw_pyramid` functions were modified to address compatibility issues with the `ColabTurtle` library's color handling.
# *   The `fillcolor()` function is not supported in `ColabTurtle`, and the `color(pencolor, fillcolor)` syntax is also unsupported.
# *   The `pencolor()` and subsequent `fillcolor()` calls were replaced with a single `color()` function call, using a single argument to set both the pen and fill color simultaneously. This ensures the shapes are drawn with the intended fill colors.
#
# ### Insights or Next Steps
# *   When working with `ColabTurtle`, always use the `color(single_color)` syntax to set both pen and fill colors for filled shapes, as `fillcolor()` and `color(pencolor, fillcolor)` are not functional.
# *   Review other custom drawing functions for similar `ColabTurtle` API limitations to ensure consistent and correct rendering of graphics.

# %%
import datetime

vojenske_letouny_list = [
    ("F-22 Raptor", "1997", 2410),
    ("F-35A Lightning II", "2006", 1930),
    ("F-16 Fighting Falcon", "1974", 2414),
    ("F/A-18E Super Hornet", "1995", 1915),
    ("F-15E Strike Eagle", "1986", 2655),

    ("Eurofighter Typhoon", "1994", 2495),
    ("Dassault Rafale", "1986", 1912),
    ("Saab JAS 39 Gripen", "1988", 2470),
    ("Panavia Tornado IDS", "1974", 2400),

    ("Sukhoi Su-35", "2008", 2400),
    ("Sukhoi Su-57", "2010", 2600),
    ("Sukhoi Su-27", "1982", 2500),
    ("Mikoyan MiG-29", "1977", 2450),
    ("Mikoyan MiG-31", "1975", 3000),

    ("Chengdu J-10", "1998", 2350),
    ("Chengdu J-20", "2011", 2100),
    ("Shenyang J-11", "1998", 2500),

    ("HAL Tejas", "2001", 2205),
    ("KAI KF-21 Boramae", "2022", 1400),

    ("McDonnell Douglas F-4 Phantom II", "1958", 2370),
    ("Mikoyan MiG-21", "1955", 2230),
    ("Lockheed F-104 Starfighter", "1954", 2400),

    ("Northrop F-5E Tiger II", "1972", 1700),
    ("Sukhoi Su-24", "1970", 1700),
    ("Sukhoi Su-30SM", "2012", 2125),
    ("Sukhoi Su-34", "1990", 1900),
    ("Mikoyan MiG-23", "1967", 2500),

    ("McDonnell Douglas AV-8B Harrier II", "1981", 1085),
    ("Fairchild Republic A-10 Thunderbolt II", "1972", 706),
    ("Boeing F-15C", "1979", 2655),
    ("Boeing F/A-18C Hornet", "1978", 1915),
    ("Lockheed Martin F-117 Nighthawk", "1981", 1035),

    ("Grumman F-14 Tomcat", "1970", 2485),
    ("Dassault Mirage 2000", "1978", 2336),
    ("Dassault Mirage III", "1956", 2200),
    ("Saab 35 Draken", "1955", 2124),
    ("Saab 37 Viggen", "1967", 2230),

    ("Tupolev Tu-22M3 Backfire", "1977", 2300),
    ("Shenyang J-8", "1969", 2330),
    ("Northrop Grumman B-2 Spirit", "1989", 1010),
    ("Rockwell B-1B Lancer", "1984", 1334),
    ("Tupolev Tu-160 Blackjack", "1981", 2200)
]




vojenske_letouny_list.append(("Boeing F-15EX Eagle II", "2021", 2655))



for model, _, _ in vojenske_letouny_list:
    print(f"— {model} —\n")


print("Seřazeno podle rychlosti:")
sezareno_podle_rychlosti = sorted(vojenske_letouny_list, key=lambda x: x[2], reverse=True)
for model, year, speed in sezareno_podle_rychlosti:
    print(f"{model} – {speed} km/h")

print()

print("Letadla, rychlejší než 2200 km/h:")
rychle_a_zbesile = [i for i in vojenske_letouny_list if i[2] > 2200]
for model, year, speed in rychle_a_zbesile:
    print(f"{model} – {speed} km/h")

fastest = max(vojenske_letouny_list, key=lambda x: x[2])
print(f"Nejrychlejší je {fastest[0]} – {fastest[2]} km/h")
print()


prum_rychlost = sum([x[2] for x in vojenske_letouny_list]) / len(vojenske_letouny_list)
print("Průměrná rychlost z celého sezanmu je", prum_rychlost)
print()


#GRAFY   (ChatGPT pomohl VELMI)

#Graf 1
import matplotlib.pyplot as plt

jmena = [x[0] for x in vojenske_letouny_list]
rychlosti = [x[2] for x in vojenske_letouny_list]

pomaly = len([x for x in rychlosti if x < 1500])
stredni = len([x for x in rychlosti if 1500 <= x < 2200])
rychle = len([x for x in rychlosti if 2200 <= x < 2600])
extremni = len([x for x in rychlosti if x >= 2600])

labels = [
    "Pomalé (<1500 km/h)",
    "Středně rychlé (1500–2199 km/h)",
    "Rychlé (2200–2599 km/h)",
    "Extrémně rychlé (≥2600 km/h)"
]

sizes = [pomaly, stredni, rychle, extremni]

plt.figure(figsize=(6, 6))
plt.pie(
    sizes,
    labels=labels,
    autopct="%1.1f%%",
    startangle=140,
    explode=(0, 0, 0.1, 0.1)
)
plt.title("Rozdělení vojenských letadel podle rychlosti")
plt.axis("equal")
plt.show()


#Graf 2
top10 = sorted(vojenske_letouny_list, key=lambda x: x[2], reverse=True)[:10]
top10_jmena = [x[0] for x in top10]
top10_rychlosti = [x[2] for x in top10]

plt.figure(figsize=(10, 6))
plt.barh(top10_jmena, top10_rychlosti)
plt.title("TOP 10 nejrychlejších vojenských letadel")
plt.xlabel("Maximální rychlost (km/h)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()


#Graf 3
import matplotlib.pyplot as plt
from datetime import datetime

aktualni_rok = datetime.now().year

# stáří letadel
stari = [aktualni_rok - int(x[1]) for x in vojenske_letouny_list]

poslednich_10 = len([s for s in stari if s <= 10])
od_11_do_20 = len([s for s in stari if 11 <= s <= 20])
od_21_do_30 = len([s for s in stari if 21 <= s <= 30])
od_31_do_50 = len([s for s in stari if 31 <= s <= 50])
nad_50 = len([s for s in stari if s > 50])


labels = [
    "Posledních 10 let",
    "11–20 let",
    "21–30 let",
    "31–50 let",
    "Více než 50 let"
]

sizes = [
    poslednich_10,
    od_11_do_20,
    od_21_do_30,
    od_31_do_50,
    nad_50
]

colors = [
    "#2ecc71",  # zelená
    "#3498db",  # modrá
    "#f1c40f",  # žlutá
    "#e67e22",  # oranžová
    "#e74c3c"   # červená
]

explode = (0.1, 0, 0, 0, 0)

plt.figure(figsize=(7, 7))
plt.pie(
    sizes,
    labels=labels,
    colors=colors,
    autopct="%1.1f%%",
    startangle=140,
    explode=explode
)
plt.title("Rozdělení vojenských letadel podle stáří")
plt.axis("equal")
plt.show()
# Out:
# — F-22 Raptor —
#
# — F-35A Lightning II —
#
# — F-16 Fighting Falcon —
#
# — F/A-18E Super Hornet —
#
# — F-15E Strike Eagle —
#
# — Eurofighter Typhoon —
#
# — Dassault Rafale —
#
# — Saab JAS 39 Gripen —
#
# — Panavia Tornado IDS —
#
# — Sukhoi Su-35 —
#
# — Sukhoi Su-57 —
#
# — Sukhoi Su-27 —
#
# — Mikoyan MiG-29 —
#
# — Mikoyan MiG-31 —
#
# — Chengdu J-10 —
#
# — Chengdu J-20 —
#
# — Shenyang J-11 —
#
# — HAL Tejas —
#
# — KAI KF-21 Boramae —
#
# — McDonnell Douglas F-4 Phantom II —
#
# — Mikoyan MiG-21 —
#
# — Lockheed F-104 Starfighter —
#
# — Northrop F-5E Tiger II —
#
# — Sukhoi Su-24 —
#
# — Sukhoi Su-30SM —
#
# — Sukhoi Su-34 —
#
# — Mikoyan MiG-23 —
#
# — McDonnell Douglas AV-8B Harrier II —
#
# — Fairchild Republic A-10 Thunderbolt II —
#
# — Boeing F-15C —
#
# — Boeing F/A-18C Hornet —
#
# — Lockheed Martin F-117 Nighthawk —
#
# — Grumman F-14 Tomcat —
#
# — Dassault Mirage 2000 —
#
# — Dassault Mirage III —
#
# — Saab 35 Draken —
#
# — Saab 37 Viggen —
#
# — Tupolev Tu-22M3 Backfire —
#
# — Shenyang J-8 —
#
# — Northrop Grumman B-2 Spirit —
#
# — Rockwell B-1B Lancer —
#
# — Tupolev Tu-160 Blackjack —
#
# — Boeing F-15EX Eagle II —
#
# Seřazeno podle rychlosti:
# Mikoyan MiG-31 – 3000 km/h
# F-15E Strike Eagle – 2655 km/h
# Boeing F-15C – 2655 km/h
# Boeing F-15EX Eagle II – 2655 km/h
# Sukhoi Su-57 – 2600 km/h
